# %%
import numpy as np
import time

# %%
arr=np.array([1,34,2,2,4])
print(arr,type(arr))
# Out:
# [ 1 34  2  2  4] <class 'numpy.ndarray'>

# %%
# execution performance
size = 10_000_000

# python list
py_list = list(range(size))

start = time.time()
sq_list = [x**2 for x in py_list]
end = time.time()

print(f"python list time = {end-start} seconds")

# numpy arrays
np_arr = np.array(py_list)

start = time.time()
sq_array = np_arr ** 2
end = time.time()

print(f"numpy array time = {end-start} seconds")
# Out:
# python list time = 0.2345259189605713 seconds
# numpy array time = 0.023914337158203125 seconds

# %%
#memory
import sys
print(f'python list size={sys.getsizeof(py_list)} bytes')
print(f'numpy array size={np_arr.nbytes}bytes')
# Out:
# python list size=80000056 bytes
# numpy array size=80000000bytes
