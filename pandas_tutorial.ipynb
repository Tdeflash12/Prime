# %%
import pandas as pd

# %%
s=pd.Series([1,2,3,4,5])
print(s)
print(type(s))

#index
print(s[0])
print(s[1])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>
# 1
# 2

# %%
s=pd.Series([23,12,24,52],index=["Adam","Ram","Hari","Hero"])
print(s)
print(s['Adam'])
print(s["Hari"])
print(s[1])
print(s.index)
# Out:
# Adam    23
# Ram     12
# Hari    24
# Hero    52
# dtype: int64
# 23
# 24
# 12
# Index(['Adam', 'Ram', 'Hari', 'Hero'], dtype='object')
# /var/folders/wf/bm25hvvn46s6x72gggcqvm380000gn/T/ipykernel_54827/1365196873.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[1])

# %%
s1=pd.Series([2,3,5,3,2])
s2=pd.Series([10,20,30,40,50])
print(s1+s2)

s1[0]=100
changed_s1=s1.drop(0)
print(s1)
print(changed_s1)
# Out:
# 0    12
# 1    23
# 2    35
# 3    43
# 4    52
# dtype: int64
# 0    100
# 1      3
# 2      5
# 3      3
# 4      2
# dtype: int64
# 1    3
# 2    5
# 3    3
# 4    2
# dtype: int64
